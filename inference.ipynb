# %%
from fastai import *
import json
from fastai.vision import *

# %%
with open('classes.json') as classes:
    cats = json.load(classes)

# %%
cats = json.loads(cats)

# %%
# cats

# %%
learn=load_learner('model/')

# %%
img=open_image('test_images/test.jpeg')

# %%
img
# Out:
# Image (3, 1280, 960)

# %%
cats[f'{learn.predict(img)[1].item()}']
# Out:
# 'pug'
